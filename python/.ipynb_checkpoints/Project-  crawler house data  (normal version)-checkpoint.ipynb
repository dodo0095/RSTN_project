# %%
import sys
import requests
from zipfile import ZipFile
import pandas as pd
import json

# 爬蟲function
def download_file(url, fileName):
    r = requests.get(url, stream=True)
    if r.status_code == 200: # HTTP 200 OK
        if r.headers['Content-Type'] == 'application/octet-stream': # zip檔串流
            size = r.headers['Content-Length'] # zip檔大小
            print('file size: {} bytes'.format(size))   #觀看檔案大小

            # 執行下載過程
            with open(fileName, 'wb') as f: # 在本地路徑開檔
                count = 0
                for chunk in r.iter_content(chunk_size=1024):  # 緩衝下載
                    if chunk: # 過濾掉保持活躍的新塊
                        f.write(chunk) # 寫入
                        # 計算下載進度
                        count += len(chunk)
                        #print('{}: {:3d}%'.format(fileName, int(count / int(size) * 100)))    #可以觀看下載進度
                    else:
                        print('no chunk')
            r.close() # 關閉 Response
            return fileName
        else:
            print('content type is not zip file.')
            r.close() # 關閉 Response
            return None
    else:
        print('request failed')
        r.close() # 關閉 Response
        return None
#中文 跟阿拉伯數字轉換    
number_map = {
"零": 0,
"一": 1,
"二": 2,
"三": 3,
"四": 4,
"五": 5,
"六": 6,
"七": 7,
"八": 8,
"九": 9
}

#爬蟲   輸入年份   (題目指定是108S2)
year=input("你要哪一個年份的資料 (民國)")
season=input("你要哪一季的資料  輸入數字 1~4")
url="http://plvr.land.moi.gov.tw/DownloadSeason?season="+year+"S"+season+"&type=zip&fileName=lvr_landcsv.zip"
download_file(url, year+"S"+season+".zip")

# 輸入想要看的數據資料    # 題目預設為   主要用途為 (住家用) 建物型態為  (住宅大樓)    樓層在13樓以上
how_to_use=input("你想查的房子 主要用途為?  (住家用,商業用,工業用,停車用....)")
house_type=input("你想查的房子 建物型態為?  (住宅大樓,套房,公寓....)")
house_level=input("你想查的房子 總樓層數希望大於等於幾層樓?  輸入阿拉伯數字 5,6,10....")


#開啟要跑的縣市    可寫轉換   題目指定為【臺北市/新北市/桃園市/臺中市/高雄市】的【不動產買賣】資料。
city_list=["臺北市","新北市","桃園市","臺中市","高雄市"]
city_list2=["a","f","h","b","e"]
all_city_json=[]
for city_var in range(len(city_list)):

    myzip=ZipFile(year+"S"+season+".zip")
    f=myzip.open(city_list2[city_var]+'_lvr_land_a.csv')
    df=pd.read_csv(f, encoding='utf-8')  
    #print(df)
    f.close()
    myzip.close()



    # 把中文的樓層  轉成數字
    level=df["總樓層數"].tolist()
    for i in range(len(level)):
        try:
            level[i]=level[i].replace("層","")
            if len(level[i])==1:
                level[i]=number_map[level[i]]
            elif len(level[i])==2:
                level[i]=10+number_map[level[i][1]]
            elif len(level[i])==3:
                level[i]=(number_map[level[i][0]])*10+number_map[level[i][2]]
        except:
            level[i]=0
    level[0]=0
    df["換算後的樓層數"]=level




    #根據剛剛輸入的資料   把資料篩選出來
    mask = (df["主要用途"]==how_to_use) & (df["建物型態"].str.contains(house_type)) & (df["換算後的樓層數"]>=int(house_level))  #篩選條件
    cols = ['交易年月日',"鄉鎮市區",'主要用途','建物型態','總樓層數']  #提取名稱、價格、分類欄位
    #print(df.loc[mask,cols].head(10))
    df_new=df.loc[mask,cols]


    #把json 黨輸出出來
    date_data=df_new["交易年月日"].tolist()
    date_data2=list(set(date_data))
    date_data2=sorted(date_data2)
    time_slots=[]
    for i in range(len(date_data2)):
        mask = (df_new["交易年月日"]==date_data2[i])  #篩選條件
        cols = ['交易年月日',"鄉鎮市區",'建物型態']  #提取名稱、價格、分類欄位
        df_temp=df_new.loc[mask,cols]
        events=[]
        date=date_data2[i]
        for j in range(len(df_temp)):

            district=df_temp["鄉鎮市區"].tolist()[j]
            building_state=df_temp["建物型態"].tolist()[j]

            events_dict={"district":district,"building_state":building_state}
            events.append(events_dict)
        dict_temp={"date":date,"events":events}
        time_slots.append(dict_temp)
    final={"city":city_list[city_var],"time_slots":time_slots}
    all_city_json.append(final)



#print(all_city_json)
# #輸出
with open('result-part1.json.json', 'w') as f:
     json.dump(all_city_json[0:2], f)

with open('result-result-part2.json.json.json', 'w') as f:
     json.dump(all_city_json[2:4], f)
# Out:
# 你要哪一個年份的資料 (民國)108
# 你要哪一季的資料  輸入數字 1~42
# file size: 10181487 bytes
# 你想查的房子 主要用途為?  (住家用,商業用,工業用,停車用....)住家用
# 你想查的房子 建物型態為?  (住宅大樓,套房,公寓....)住宅大樓
# 你想查的房子 總樓層數希望大於等於幾層樓?  輸入阿拉伯數字 5,6,10....13
#       交易年月日 鄉鎮市區 主要用途             建物型態  總樓層數
# 1   1071219  文山區  住家用  住宅大樓(11層含以上有電梯)  三十三層
# 11  1071105  萬華區  住家用  住宅大樓(11層含以上有電梯)  二十一層
# 13  1080115  大同區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 14  1080115  大同區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 15  1080115  大同區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 16  1080115  大同區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 17  1080115  大同區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 18  1080115  大同區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 19  1080115  大同區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 20  1080115  大同區  住家用  住宅大樓(11層含以上有電梯)   十四層
#        交易年月日 鄉鎮市區 主要用途             建物型態  總樓層數
# 2    1071214  板橋區  住家用  住宅大樓(11層含以上有電梯)  二十六層
# 151  1071207  新店區  住家用  住宅大樓(11層含以上有電梯)   十五層
# 160  1071214  淡水區  住家用  住宅大樓(11層含以上有電梯)   十五層
# 162  1070919  淡水區  住家用  住宅大樓(11層含以上有電梯)  二十七層
# 163  1020911  淡水區  住家用  住宅大樓(11層含以上有電梯)  二十七層
# 164  1071226  淡水區  住家用  住宅大樓(11層含以上有電梯)   十五層
# 239  1071204  淡水區  住家用  住宅大樓(11層含以上有電梯)   十五層
# 245  1080109  淡水區  住家用  住宅大樓(11層含以上有電梯)  二十六層
# 249  1080112  蘆洲區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 253  1071231  三重區  住家用  住宅大樓(11層含以上有電梯)   十四層
#       交易年月日 鄉鎮市區 主要用途             建物型態 總樓層數
# 3   1071226  桃園區  住家用  住宅大樓(11層含以上有電梯)  十六層
# 7   1080119  桃園區  住家用  住宅大樓(11層含以上有電梯)  十五層
# 8   1080105  桃園區  住家用  住宅大樓(11層含以上有電梯)  十三層
# 11  1071124  桃園區  住家用  住宅大樓(11層含以上有電梯)  十六層
# 13  1071230  桃園區  住家用  住宅大樓(11層含以上有電梯)  十七層
# 15  1071212  中壢區  住家用  住宅大樓(11層含以上有電梯)  十四層
# 22  1071217  楊梅區  住家用  住宅大樓(11層含以上有電梯)  十五層
# 28  1071223  八德區  住家用  住宅大樓(11層含以上有電梯)  十五層
# 29  1080110  八德區  住家用  住宅大樓(11層含以上有電梯)  十五層
# 30  1071221  八德區  住家用  住宅大樓(11層含以上有電梯)  十七層
#       交易年月日 鄉鎮市區 主要用途             建物型態  總樓層數
# 25  1071215  北屯區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 26  1071220  北屯區  住家用  住宅大樓(11層含以上有電梯)   十七層
# 28  1071231  南屯區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 30  1071230  西屯區  住家用  住宅大樓(11層含以上有電梯)  二十四層
# 33  1080118  南屯區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 34  1080105  南屯區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 39  1071208  南屯區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 43  1080104  西屯區  住家用  住宅大樓(11層含以上有電梯)  二十六層
# 53  1080109  清水區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 58  1071218  潭子區  住家用  住宅大樓(11層含以上有電梯)   十六層
#       交易年月日 鄉鎮市區 主要用途             建物型態  總樓層數
# 2   1071213  鼓山區  住家用  住宅大樓(11層含以上有電梯)  二十四層
# 3   1080122  前金區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 4   1080112  鼓山區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 20  1080106  三民區  住家用  住宅大樓(11層含以上有電梯)  二十四層
# 23  1071230  三民區  住家用  住宅大樓(11層含以上有電梯)   十五層
# 24  1071231  三民區  住家用  住宅大樓(11層含以上有電梯)  二十七層
# 27  1071229  三民區  住家用  住宅大樓(11層含以上有電梯)  二十三層
# 28  1071220  三民區  住家用  住宅大樓(11層含以上有電梯)   十四層
# 30  1080103  左營區  住家用  住宅大樓(11層含以上有電梯)   十六層
# 32  1071231  左營區  住家用  住宅大樓(11層含以上有電梯)   十四層
# [{'city': '臺北市', 'time_slots': [{'date': '1011220', 'events': [{'district': '內湖區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1020215', 'events': [{'district': '士林區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1021206', 'events': [{'district': '內湖區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1040713', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}, {'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1040718', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1040725', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1040916', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1040923', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1041001', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1050202', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1050319', 'events': [{'district': '大安區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1050422', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}, {'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1050513', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1050624', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1050714', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1050715', 'events': [{'district': '大安區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1050825', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1051007', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1051011', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1051216', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1060108', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1060122', 'events': [{'district': '中山區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1060312', 'events': [{'district': '大安區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1060406', 'events': [{'district': '萬華區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1060614', 'events': [{'district': '大安區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1060906', 'events': [{'district': '中山區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061002', 'events': [{'district': '中山區', 'building_state': '住宅大樓(11層含以上有電梯)'}, {'district': '中山區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061009', 'events': [{'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061010', 'events': [{'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061011', 'events': [{'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}, {'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061015', 'events': [{'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}, {'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}, {'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061024', 'events': [{'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061025', 'events': [{'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061028', 'events': [{'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}, {'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}, {'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}, {'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061102', 'events': [{'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}, {'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061103', 'events': [{'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061113', 'events': [{'district': '大同區', 'building_state': '住宅大樓(11層含以上有電梯)'}]}, {'date': '1061115', ' ...

# %%
with open('result-part1.json.json', 'w', encoding='utf-8') as f:
     json.dump(all_city_json[0:2], f,ensure_ascii=False)

with open('result-part2.json', 'w', encoding='utf-8') as f:
     json.dump(all_city_json[2:4], f,ensure_ascii=False)
